# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#Преобразования номера в вид 79991234567
#data - название входящего dataframe
#name - имя колонки содержащей номер
#new_name - имя новой колонки с номером
def number_norm(data, name, new_name):  
    
    #создаем dataframe для внутренних преобразований
    df = data.copy()
    
    #Вставляем новый столбец для номера и проверяем есть ли он уже
    try:
        df.insert(loc=0 , column=new_name, value=df[name])
    except ValueError:
        #если он уже есть проверяем что новый столбец соответствует старому
        if df[new_name][0] == df[name][0]:
            pass
        else:            
            print('Выбери другое имя нового столбца!')
            return
    
    #функция для преобразования строки с номером
    #n - строка
    def number_change(n):
        #посимвольно проверяем строку n, цифры записываем в строку r, остальное отбрасываем
        try:
            r = ''
            for i in n:
                if i.isdigit():
                    r += str(i)
        #в случае возникновения проблемы при проверке возвращаем None
        except TypeError:
            return None
        #при удачном преобразовании:
        else:
            # создаем новую переменную в которую будем записывать конечный результат, 
            # если получившийся набор цифр не соответствует нашим требованиям к номеру будем возвращать None
            r1 = None
            # проверяем что номер не более 11 цифр и удаляем лишнее
            if len(r) > 10:        
                r = r[0:11]
                # оставляем если в начяле стоит 7
                if r[0] == '7':
                    r1 = r
                # заменяем в начале 8 на 7
                elif r[0] == '8':
                    r1 = '7' + r[1:]
            # если номер записан без 8 или +7 добавляем 7
            elif len(r) == 10:
                r1 = '7' + r
        return r1
    
    display(df.shape)
    df[new_name] = df[new_name].map(number_change)
    df_dropna = df.dropna(subset=[new_name], ignore_index=True)
    #display(df_dropna.info())
    display(df.shape[0]-df_dropna.shape[0])
    #display(df_dropna)
    return(df_dropna)

# %%
contact_a = pd.read_csv('CONTACT_а.csv', dtype=str)
display(contact_a)
# Out:
#               Название      Телефон Емейл Регион Последняя активность  \
# 0               Гофман          NaN   NaN    NaN  03.08.2023 11:01:42
# 1              Алексей  79875151111   NaN    NaN  22.05.2023 12:12:04
# 2                Дарья  79956054851   NaN    NaN  28.10.2023 10:56:51
# 3               ШАМИЛЬ   9168093955   NaN    NaN  01.02.2023 14:22:57
# 4            АЛЕКСАНДР   9104489851   NaN    NaN  01.02.2023 14:22:57
# ...                ...          ...   ...    ...                  ...
# 100751       Регламент   9999999999   NaN    NaN  18.01.2023 17:41:01
# 100752         Михаил   79233648545   NaN    NaN  22.03.2024 15:13:46
# 100753  Отец Александр  79212238584   NaN    NaN  17.04.2024 11:09:52
# 100754          Андрей  79504024285   NaN    NaN  14.06.2024 10:41:14
# 100755           Ринат  79163479836   NaN    NaN  28.02.2023 20:45:30
#
#               Дата создания                        Источник Стадия Техника  \
# ...

# %%
contact_a['Телефон'].isnull().value_counts()
# Out:
# Телефон
# False    100755
# True          1
# Name: count, dtype: int64

# %%
cont_a = number_norm(data = contact_a, name = 'Телефон', new_name='number')
# Out:
# (100756, 11)
# 7332

# %%
contact_b = pd.read_csv('CONTACT_б.csv', dtype=str)
display(contact_b)
contact_b['Телефон'].isnull().value_counts()
# Out:
#        Название      Телефон E-mail Регион Последняя активность  \
# 0         БОРИС   9859975250    NaN    NaN  01.02.2023 14:22:55
# 1        ЛЮБОВЬ  89164953314    NaN    NaN  01.02.2023 14:22:47
# 2         БОРИС  89037903182    NaN    NaN  01.02.2023 14:22:46
# 3        ЗУРАБИ  89257808344    NaN    NaN  01.02.2023 14:22:30
# 4      АСЛАНБЕК  89264340034    NaN    NaN  01.02.2023 14:22:29
# ...         ...          ...    ...    ...                  ...
# 2442    СИЯБШАХ  89153093454    NaN    NaN  01.02.2023 10:17:59
# 2443     ЛЮБОВЬ  79035350847    NaN    NaN  01.02.2023 10:17:59
# 2444  ДЖАМБУЛАТ  89261019190    NaN    NaN  01.02.2023 10:17:59
# 2445   ЭЛЬБУРУС      1873187    NaN    NaN  01.02.2023 10:17:58
# 2446     МЕХРАБ  89269222122    NaN    NaN  01.02.2023 10:17:55
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:55  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_b = number_norm(data = contact_b, name = 'Телефон', new_name='number')
# Out:
# (2447, 11)
# 187

# %%
contact_v = pd.read_csv('CONTACT_в.csv', dtype=str)
display(contact_v)
contact_v['Телефон'].isnull().value_counts()
# Out:
#         Название               Телефон E-mail Регион Последняя активность  \
# 0         ВИКТОР            9264727051    NaN    NaN  01.02.2023 14:22:57
# 1       СВЕТЛАНА           89161245746    NaN    NaN  01.02.2023 14:22:57
# 2       СВЕТЛАНА            9260976232    NaN    NaN  01.02.2023 14:22:56
# 3        ВИТАЛИЙ            9057860022    NaN    NaN  01.02.2023 14:22:55
# 4       ВЛАДИМИР            9161539150    NaN    NaN  01.02.2023 14:22:54
# ...          ...                   ...    ...    ...                  ...
# 28167  СТАНИСЛАВ            9268880606    NaN    NaN  01.02.2023 10:17:56
# 28168    ВЛАДЛЕН  2200224, 89167594897    NaN    NaN  01.02.2023 10:17:56
# 28169    ЯРОСЛАВ           84957680432    NaN    NaN  01.02.2023 10:17:56
# 28170      ВАДИМ           89037990302    NaN    NaN  01.02.2023 10:17:55
# 28171     ВИКТОР           89251003545    NaN    NaN  01.02.2023 10:17:55
#
#              Дата создания                        Источник Стадия Техника База
# ...

# %%
cont_v = number_norm(data = contact_v, name = 'Телефон', new_name='number')
# Out:
# (28172, 11)
# 2182

# %%
contact_g = pd.read_csv('CONTACT_г.csv', dtype=str)
display(contact_g)
contact_g['Телефон'].isnull().value_counts()
# Out:
#         Название                    Телефон E-mail Регион  \
# 0         Гофман                        NaN    NaN    NaN
# 1          ИГОРЬ                89161953242    NaN    NaN
# 2           ОЛЕГ                89266121362    NaN    NaN
# 3         СЕРГЕЙ                89260611137    NaN    NaN
# 4        ЕВГЕНИЙ                89267136433    NaN    NaN
# ...          ...                        ...    ...    ...
# 24803     Сергей                79163697872    NaN    NaN
# 24804    Георгий  +79536660952, 79809009417    NaN    NaN
# 24805  Регламент                 9999999999    NaN    NaN
# 24806     Сергей                79994505505    NaN    NaN
# 24807       Егор                79135937038    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      03.08.2023 11:01:42  03.08.2023 11:01:42
# 1      01.02.2023 14:22:55  01.02.2023 14:22:55
# 2      01.02.2023 14:22:55  01.02.2023 14:22:55
# 3      01.02.2023 14:22:54  01.02.2023 14:22:54
# ...

# %%
cont_g = number_norm(data = contact_g, name = 'Телефон', new_name='number')
# Out:
# (24808, 11)
# 1884

# %%
contact_d = pd.read_csv('CONTACT_д.csv', dtype=str)
display(contact_d)
contact_d['Телефон'].isnull().value_counts()
# Out:
#              Название                   Телефон E-mail Регион  \
# 0               Дарья               79956054851    NaN    NaN
# 1           АЛЕКСАНДР                9104489851    NaN    NaN
# 2                ДИНА               89175354909    NaN    NaN
# 3               ЛИДИЯ               89263553399    NaN    NaN
# 4               ФЕДОР               89037645663    NaN    NaN
# ...               ...                       ...    ...    ...
# 34820          ЛЕОНИД               89263571731    NaN    NaN
# 34821           ВАДИМ               89037990302    NaN    NaN
# 34822       АЛЕКСАНДР  89288805767, 89688274437    NaN    NaN
# 34823  Отец Александр               79212238584    NaN    NaN
# 34824          Андрей               79504024285    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      28.10.2023 10:56:51  28.03.2023 11:53:27
# 1      01.02.2023 14:22:57  01.02.2023 14:22:57
# 2      01.02.2023 14:22:56  01.02.2023 14:22:56
# ...

# %%
cont_d = number_norm(data = contact_d, name = 'Телефон', new_name='number')
# Out:
# (34825, 11)
# 2851

# %%
contact_e = pd.read_csv('CONTACT_е.csv', dtype=str)
display(contact_e)
contact_e['Телефон'].isnull().value_counts()
# Out:
#              Название      Телефон E-mail Регион Последняя активность  \
# 0             Алексей  79875151111    NaN    NaN  22.05.2023 12:12:04
# 1           АЛЕКСАНДР   9104489851    NaN    NaN  01.02.2023 14:22:57
# 2             АЛЕКСЕЙ  89250069996    NaN    NaN  01.02.2023 14:22:57
# 3           ЕКАТЕРИНА  89645111050    NaN    NaN  01.02.2023 14:22:57
# 4            СВЕТЛАНА  89161245746    NaN    NaN  01.02.2023 14:22:57
# ...               ...          ...    ...    ...                  ...
# 60119       Регламент   9999999999    NaN    NaN  18.01.2023 17:41:01
# 60120          Сергей  79994505505    NaN    NaN  11.01.2023 23:25:56
# 60121            Егор  79135937038    NaN    NaN  27.12.2022 13:00:01
# 60122  Отец Александр  79212238584    NaN    NaN  17.04.2024 11:09:52
# 60123          Андрей  79504024285    NaN    NaN  14.06.2024 10:41:14
#
#              Дата создания                        Источник Стадия Техника База
# ...

# %%
cont_e = number_norm(data = contact_e, name = 'Телефон', new_name='number')
# Out:
# (60124, 11)
# 4597

# %%
contact_j = pd.read_csv('CONTACT_ж.csv', dtype=str)
display(contact_j)
contact_j['Телефон'].isnull().value_counts()
# Out:
#        Название      Телефон E-mail Регион Последняя активность  \
# 0         ЖАННА  89269265202    NaN    NaN  01.02.2023 14:22:54
# 1        ДЖАЛИЛ   9037903625    NaN    NaN  01.02.2023 14:22:52
# 2       НАДЕЖДА  89853087070    NaN    NaN  01.02.2023 14:22:49
# 3       НАДЕЖДА   9267227833    NaN    NaN  01.02.2023 14:22:38
# 4       НАДЕЖДА      5777454    NaN    NaN  01.02.2023 14:22:23
# ...         ...          ...    ...    ...                  ...
# 1862  ДЖУЛЬЕТТА   9168888005    NaN    NaN  01.02.2023 10:18:21
# 1863  ГАДЖИКУЛИ   9857671119    NaN    NaN  01.02.2023 10:18:19
# 1864    СНЕЖАНА  89055617035    NaN    NaN  01.02.2023 10:18:19
# 1865    МЕРУЖАН   9257724818    NaN    NaN  01.02.2023 10:18:15
# 1866  ДЖАМБУЛАТ  89261019190    NaN    NaN  01.02.2023 10:17:59
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:54  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_j = number_norm(data = contact_j, name = 'Телефон', new_name='number')
# Out:
# (1867, 11)
# 113

# %%
contact_z = pd.read_csv('CONTACT_з.csv', dtype=str)
display(contact_z)
contact_z['Телефон'].isnull().value_counts()
# Out:
#      Название      Телефон E-mail Регион Последняя активность  \
# 0       ЛУИЗА  89265610737    NaN    NaN  01.02.2023 14:22:55
# 1        РАЗИ  89645036303    NaN    NaN  01.02.2023 14:22:47
# 2      РАМЗАН  89160915868    NaN    NaN  01.02.2023 14:22:31
# 3      ЗУРАБИ  89257808344    NaN    NaN  01.02.2023 14:22:30
# 4       НАЗИР  89037243445    NaN    NaN  01.02.2023 14:22:23
# ...       ...          ...    ...    ...                  ...
# 1469   РАМАЗИ  89095384400    NaN    NaN  01.02.2023 10:18:11
# 1470   ТЕНГИЗ   9852260937    NaN    NaN  01.02.2023 10:18:10
# 1471     АЗЕР  89266606646    NaN    NaN  01.02.2023 10:18:04
# 1472    ЗАКИР  89252204581    NaN    NaN  01.02.2023 10:18:02
# 1473  РИЗИУАН  89152222877    NaN    NaN  01.02.2023 10:17:58
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:55  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_z = number_norm(data = contact_z, name = 'Телефон', new_name='number')
# Out:
# (1474, 11)
# 102

# %%
contact_i = pd.read_csv('CONTACT_и.csv', dtype=str)
display(contact_i)
contact_i['Телефон'].isnull().value_counts()
# Out:
#         Название                    Телефон E-mail Регион  \
# 0           Тони                        NaN    NaN    NaN
# 1         ШАМИЛЬ                 9168093955    NaN    NaN
# 2        НИКОЛАЙ                 9032430607    NaN    NaN
# 3         ИСМАИЛ                89637768497    NaN    NaN
# 4      ЕКАТЕРИНА                89645111050    NaN    NaN
# ...          ...                        ...    ...    ...
# 70492     ВИКТОР                89251003545    NaN    NaN
# 70493       Илья                79164458410    NaN    NaN
# 70494    Георгий  +79536660952, 79809009417    NaN    NaN
# 70495    Михаил                 79233648545    NaN    NaN
# 70496      Ринат                79163479836    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      01.09.2023 16:18:42  01.09.2023 16:18:42
# 1      01.02.2023 14:22:57  01.02.2023 14:22:57
# 2      01.02.2023 14:22:57  01.02.2023 14:22:57
# 3      01.02.2023 14:22:57  01.02.2023 14:22:57
# ...

# %%
cont_i = number_norm(data = contact_i, name = 'Телефон', new_name='number')
# Out:
# (70497, 11)
# 5279

# %%
contact_ii = pd.read_csv('CONTACT_й.csv', dtype=str)
display(contact_ii)
contact_ii['Телефон'].isnull().value_counts()
# Out:
#        Название                    Телефон E-mail Регион Последняя активность  \
# 0       Алексей                79875151111    NaN    NaN  22.05.2023 12:12:04
# 1       АЛЕКСЕЙ                89250069996    NaN    NaN  01.02.2023 14:22:57
# 2       НИКОЛАЙ                 9032430607    NaN    NaN  01.02.2023 14:22:57
# 3      АНАТОЛИЙ                89037623345    NaN    NaN  01.02.2023 14:22:57
# 4          ЮРИЙ                89266516894    NaN    NaN  01.02.2023 14:22:57
# ...         ...                        ...    ...    ...                  ...
# 39876    СЕРГЕЙ                 9096636494    NaN    NaN  01.02.2023 10:17:55
# 39877    Сергей                79163697872    NaN    NaN  12.04.2023 17:25:27
# 39878   Георгий  +79536660952, 79809009417    NaN    NaN  25.01.2023 01:49:13
# 39879    Сергей                79994505505    NaN    NaN  11.01.2023 23:25:56
# 39880    Андрей                79504024285    NaN    NaN  14.06.2024 10:41:14
#
# ...

# %%
cont_ii = number_norm(data = contact_ii, name = 'Телефон', new_name='number')
# Out:
# (39881, 11)
# 3308

# %%
contact_k = pd.read_csv('CONTACT_к.csv', dtype=str)
display(contact_k)
contact_k['Телефон'].isnull().value_counts()
# Out:
#              Название                   Телефон E-mail Регион  \
# 0             Алексей               79875151111    NaN    NaN
# 1           АЛЕКСАНДР                9104489851    NaN    NaN
# 2             АЛЕКСЕЙ               89250069996    NaN    NaN
# 3             НИКОЛАЙ                9032430607    NaN    NaN
# 4           ЕКАТЕРИНА               89645111050    NaN    NaN
# ...               ...                       ...    ...    ...
# 30741       АЛЕКСАНДР               89057797197    NaN    NaN
# 30742         НИКОЛАЙ               89166024358    NaN    NaN
# 30743       АЛЕКСАНДР  89288805767, 89688274437    NaN    NaN
# 30744          ВИКТОР               89251003545    NaN    NaN
# 30745  Отец Александр               79212238584    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      22.05.2023 12:12:04  26.04.2023 11:21:55
# 1      01.02.2023 14:22:57  01.02.2023 14:22:57
# 2      01.02.2023 14:22:57  01.02.2023 14:22:57
# ...

# %%
cont_k = number_norm(data = contact_k, name = 'Телефон', new_name='number')
# Out:
# (30746, 11)
# 2346

# %%
contact_l = pd.read_csv('CONTACT_л.csv', dtype=str)
display(contact_l)
contact_l['Телефон'].isnull().value_counts()
# Out:
#              Название                   Телефон E-mail Регион  \
# 0             Алексей               79875151111    NaN    NaN
# 1              ШАМИЛЬ                9168093955    NaN    NaN
# 2           АЛЕКСАНДР                9104489851    NaN    NaN
# 3             АЛЕКСЕЙ               89250069996    NaN    NaN
# 4             НИКОЛАЙ                9032430607    NaN    NaN
# ...               ...                       ...    ...    ...
# 67457       АЛЕКСАНДР  89288805767, 89688274437    NaN    NaN
# 67458            Илья               79164458410    NaN    NaN
# 67459       Регламент                9999999999    NaN    NaN
# 67460         Михаил                79233648545    NaN    NaN
# 67461  Отец Александр               79212238584    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      22.05.2023 12:12:04  26.04.2023 11:21:55
# 1      01.02.2023 14:22:57  01.02.2023 14:22:57
# 2      01.02.2023 14:22:57  01.02.2023 14:22:57
# ...

# %%
cont_l = number_norm(data = contact_l, name = 'Телефон', new_name='number')
# Out:
# (67462, 11)
# 5198

# %%
contact_m = pd.read_csv('CONTACT_м.csv', dtype=str)
display(contact_m)
contact_m['Телефон'].isnull().value_counts()
# Out:
#         Название      Телефон E-mail Регион Последняя активность  \
# 0         Гофман          NaN    NaN    NaN  03.08.2023 11:01:42
# 1         ШАМИЛЬ   9168093955    NaN    NaN  01.02.2023 14:22:57
# 2         ИСМАИЛ  89637768497    NaN    NaN  01.02.2023 14:22:57
# 3          РОМАН  89031888883    NaN    NaN  01.02.2023 14:22:57
# 4         МИХАИЛ   9099500701    NaN    NaN  01.02.2023 14:22:55
# ...          ...          ...    ...    ...                  ...
# 26455      ВАДИМ  89037990302    NaN    NaN  01.02.2023 10:17:55
# 26456      МАХАЧ  89104506694    NaN    NaN  01.02.2023 10:17:55
# 26457     МЕХРАБ  89269222122    NaN    NaN  01.02.2023 10:17:55
# 26458  Регламент   9999999999    NaN    NaN  18.01.2023 17:41:01
# 26459    Михаил   79233648545    NaN    NaN  22.03.2024 15:13:46
#
#              Дата создания                        Источник Стадия Техника База
# 0      03.08.2023 11:01:42                          Звонок    NaN     NaN  NaN
# ...

# %%
cont_m = number_norm(data = contact_m, name = 'Телефон', new_name='number')
# Out:
# (26460, 11)
# 2007

# %%
contact_n = pd.read_csv('CONTACT_н.csv', dtype=str)
display(contact_n)
contact_n['Телефон'].isnull().value_counts()
# Out:
#              Название      Телефон E-mail Регион Последняя активность  \
# 0                Тони          NaN    NaN    NaN  01.09.2023 16:18:42
# 1              Гофман          NaN    NaN    NaN  03.08.2023 11:01:42
# 2           АЛЕКСАНДР   9104489851    NaN    NaN  01.02.2023 14:22:57
# 3             НИКОЛАЙ   9032430607    NaN    NaN  01.02.2023 14:22:57
# 4           ЕКАТЕРИНА  89645111050    NaN    NaN  01.02.2023 14:22:57
# ...               ...          ...    ...    ...                  ...
# 67101         ТАТЬЯНА  89262651187    NaN    NaN  01.02.2023 10:17:55
# 67102       Регламент   9999999999    NaN    NaN  18.01.2023 17:41:01
# 67103  Отец Александр  79212238584    NaN    NaN  17.04.2024 11:09:52
# 67104          Андрей  79504024285    NaN    NaN  14.06.2024 10:41:14
# 67105           Ринат  79163479836    NaN    NaN  28.02.2023 20:45:30
#
#              Дата создания                        Источник Стадия Техника База
# ...

# %%
cont_n = number_norm(data = contact_n, name = 'Телефон', new_name='number')
# Out:
# (67106, 11)
# 4733

# %%
contact_o = pd.read_csv('CONTACT_о.csv', dtype=str)
display(contact_o)
contact_o['Телефон'].isnull().value_counts()
# Out:
#              Название                    Телефон E-mail Регион  \
# 0                Тони                        NaN    NaN    NaN
# 1              Гофман                        NaN    NaN    NaN
# 2             НИКОЛАЙ                 9032430607    NaN    NaN
# 3              ВИКТОР                 9264727051    NaN    NaN
# 4            АНАТОЛИЙ                89037623345    NaN    NaN
# ...               ...                        ...    ...    ...
# 25859         НИКОЛАЙ                89166024358    NaN    NaN
# 25860          ВИКТОР                89251003545    NaN    NaN
# 25861         Георгий  +79536660952, 79809009417    NaN    NaN
# 25862            Егор                79135937038    NaN    NaN
# 25863  Отец Александр                79212238584    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      01.09.2023 16:18:42  01.09.2023 16:18:42
# 1      03.08.2023 11:01:42  03.08.2023 11:01:42
# 2      01.02.2023 14:22:57  01.02.2023 14:22:57
# ...

# %%
cont_o = number_norm(data = contact_o, name = 'Телефон', new_name='number')
# Out:
# (25864, 11)
# 1910

# %%
contact_p = pd.read_csv('CONTACT_п.csv', dtype=str)
display(contact_p)
contact_p['Телефон'].isnull().value_counts()
# Out:
#      Название      Телефон E-mail Регион Последняя активность  \
# 0       ПАВЕЛ  89645008430    NaN    NaN  01.02.2023 14:22:53
# 1       ПАВЕЛ  89263439242    NaN    NaN  01.02.2023 14:22:53
# 2       ПАВЕЛ      7903359    NaN    NaN  01.02.2023 14:22:47
# 3      ПОЛИНА   9264112913    NaN    NaN  01.02.2023 14:22:46
# 4       ПАВЕЛ   9166791161    NaN    NaN  01.02.2023 14:22:45
# ...       ...          ...    ...    ...                  ...
# 2910    ПАВЕЛ  89030014599    NaN    NaN  01.02.2023 10:18:15
# 2911   ФИЛИПП  89037829787    NaN    NaN  01.02.2023 10:18:11
# 2912    ПАВЕЛ   9165607524    NaN    NaN  01.02.2023 10:18:10
# 2913     АКОП  89261235412    NaN    NaN  01.02.2023 10:17:57
# 2914    ПАВЕЛ  89265212508    NaN    NaN  01.02.2023 10:17:56
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:53  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_p = number_norm(data = contact_p, name = 'Телефон', new_name='number')
# Out:
# (2915, 11)
# 192

# %%
contact_c = pd.read_csv('CONTACT_с.csv', dtype=str)
display(contact_c)
contact_c['Телефон'].isnull().value_counts()
# Out:
#              Название                   Телефон E-mail Регион  \
# 0             Алексей               79875151111    NaN    NaN
# 1           АЛЕКСАНДР                9104489851    NaN    NaN
# 2             АЛЕКСЕЙ               89250069996    NaN    NaN
# 3              ИСМАИЛ               89637768497    NaN    NaN
# 4            СВЕТЛАНА               89161245746    NaN    NaN
# ...               ...                       ...    ...    ...
# 41200          СЕРГЕЙ                9096636494    NaN    NaN
# 41201       АЛЕКСАНДР  89288805767, 89688274437    NaN    NaN
# 41202          Сергей               79163697872    NaN    NaN
# 41203          Сергей               79994505505    NaN    NaN
# 41204  Отец Александр               79212238584    NaN    NaN
#
#       Последняя активность        Дата создания  \
# 0      22.05.2023 12:12:04  26.04.2023 11:21:55
# 1      01.02.2023 14:22:57  01.02.2023 14:22:57
# 2      01.02.2023 14:22:57  01.02.2023 14:22:57
# ...

# %%
cont_c = number_norm(data = contact_c, name = 'Телефон', new_name='number')
# Out:
# (41205, 11)
# 3160

# %%
contact_t = pd.read_csv('CONTACT_т.csv', dtype=str)
display(contact_t)
contact_t['Телефон'].isnull().value_counts()
# Out:
#              Название      Телефон E-mail Регион Последняя активность  \
# 0                Тони          NaN    NaN    NaN  01.09.2023 16:18:42
# 1           ЕКАТЕРИНА  89645111050    NaN    NaN  01.02.2023 14:22:57
# 2              ВИКТОР   9264727051    NaN    NaN  01.02.2023 14:22:57
# 3            СВЕТЛАНА  89161245746    NaN    NaN  01.02.2023 14:22:57
# 4            АНАТОЛИЙ  89037623345    NaN    NaN  01.02.2023 14:22:57
# ...               ...          ...    ...    ...                  ...
# 32194          ВИКТОР  89251003545    NaN    NaN  01.02.2023 10:17:55
# 32195         ТАТЬЯНА  89262651187    NaN    NaN  01.02.2023 10:17:55
# 32196       Регламент   9999999999    NaN    NaN  18.01.2023 17:41:01
# 32197  Отец Александр  79212238584    NaN    NaN  17.04.2024 11:09:52
# 32198           Ринат  79163479836    NaN    NaN  28.02.2023 20:45:30
#
#              Дата создания                        Источник Стадия Техника База
# ...

# %%
cont_t = number_norm(data = contact_t, name = 'Телефон', new_name='number')
# Out:
# (32199, 11)
# 2220

# %%
contact_y = pd.read_csv('CONTACT_у.csv', dtype=str)
display(contact_y)
contact_y['Телефон'].isnull().value_counts()
# Out:
#        Название      Телефон E-mail Регион Последняя активность  \
# 0         ЛУИЗА  89265610737    NaN    NaN  01.02.2023 14:22:55
# 1          ДАУТ  89037444999    NaN    NaN  01.02.2023 14:22:54
# 2         ТИМУР   9167084228    NaN    NaN  01.02.2023 14:22:46
# 3        РУСЛАН  89096690127    NaN    NaN  01.02.2023 14:22:43
# 4        ЭДУАРД   9057071978    NaN    NaN  01.02.2023 14:22:38
# ...         ...          ...    ...    ...                  ...
# 3445  ДЖАМБУЛАТ  89261019190    NaN    NaN  01.02.2023 10:17:59
# 3446   ЭЛЬБУРУС      1873187    NaN    NaN  01.02.2023 10:17:58
# 3447    РИЗИУАН  89152222877    NaN    NaN  01.02.2023 10:17:58
# 3448     РЕ ЧУН  89037978877    NaN    NaN  01.02.2023 10:17:57
# 3449     РУСЛАН      9162572    NaN    NaN  01.02.2023 10:17:55
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:55  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_y = number_norm(data = contact_y, name = 'Телефон', new_name='number')
# Out:
# (3450, 11)
# 189

# %%
contact_f = pd.read_csv('CONTACT_ф.csv', dtype=str)
display(contact_f)
contact_f['Телефон'].isnull().value_counts()
# Out:
#      Название               Телефон E-mail Регион Последняя активность  \
# 0      Гофман                   NaN    NaN    NaN  03.08.2023 11:01:42
# 1       ФЕДОР           89037645663    NaN    NaN  01.02.2023 14:22:55
# 2       РАФАТ            9257038838    NaN    NaN  01.02.2023 14:22:54
# 3       ТОФИК           89153305586    NaN    NaN  01.02.2023 14:22:46
# 4     РАФАЭЛЬ           89851949408    NaN    NaN  01.02.2023 14:22:36
# ...       ...                   ...    ...    ...                  ...
# 1253   ФИЛИПП           89852746445    NaN    NaN  01.02.2023 10:18:17
# 1254     ЕФИМ           89264523304    NaN    NaN  01.02.2023 10:18:11
# 1255   ФИЛИПП           89037829787    NaN    NaN  01.02.2023 10:18:11
# 1256    ФЕДОР  79857630447, 7630447    NaN    NaN  01.02.2023 10:18:02
# 1257    РАФИГ            9168370220    NaN    NaN  01.02.2023 10:18:02
#
#             Дата создания                        Источник Стадия Техника База
# ...

# %%
cont_f = number_norm(data = contact_f, name = 'Телефон', new_name='number')
# Out:
# (1258, 11)
# 100

# %%
contact_x = pd.read_csv('CONTACT_х.csv', dtype=str)
display(contact_x)
contact_x['Телефон'].isnull().value_counts()
# Out:
#      Название      Телефон E-mail Регион Последняя активность  \
# 0      МИХАИЛ   9099500701    NaN    NaN  01.02.2023 14:22:55
# 1      МИХАИЛ  89857912640    NaN    NaN  01.02.2023 14:22:44
# 2       ШАХИН  89035593536    NaN    NaN  01.02.2023 14:22:42
# 3      МИХАИЛ  89104195984    NaN    NaN  01.02.2023 14:22:37
# 4      МИХАИЛ  89153399608    NaN    NaN  01.02.2023 14:22:36
# ...       ...          ...    ...    ...                  ...
# 4318   МИХАИЛ  89104763573    NaN    NaN  01.02.2023 10:18:02
# 4319  СИЯБШАХ  89153093454    NaN    NaN  01.02.2023 10:17:59
# 4320    МАХАЧ  89104506694    NaN    NaN  01.02.2023 10:17:55
# 4321   МЕХРАБ  89269222122    NaN    NaN  01.02.2023 10:17:55
# 4322  Михаил   79233648545    NaN    NaN  22.03.2024 15:13:46
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:55  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_x = number_norm(data = contact_x, name = 'Телефон', new_name='number')
# Out:
# (4323, 11)
# 338

# %%
contact_cc = pd.read_csv('CONTACT_ц.csv', dtype=str)
display(contact_cc)
contact_cc['Телефон'].isnull().value_counts()
# Out:
#           Название      Телефон E-mail Регион Последняя активность  \
# 0            ЦОЛАК  89262724310    NaN    NaN  01.02.2023 14:22:23
# 1            ЦОТНЕ   9267644649    NaN    NaN  01.02.2023 14:09:46
# 2           ЦАНДЫК  89651222809    NaN    NaN  01.02.2023 14:08:55
# 3            ЦОЛАК  89250380108    NaN    NaN  01.02.2023 14:07:20
# 4         МНАЦАКАН  89645130560    NaN    NaN  01.02.2023 14:05:15
# ..             ...          ...    ...    ...                  ...
# 84         ГУАНЦЗИ  89265055651    NaN    NaN  01.02.2023 10:27:52
# 85        ЦЫДЫПЖАП  89160894795    NaN    NaN  01.02.2023 10:27:04
# 86        АВИЦЕННА  89104227627    NaN    NaN  01.02.2023 10:25:00
# 87           ЦЗЮНЬ  89265168333    NaN    NaN  01.02.2023 10:19:25
# 88  Отец Александр  79212238584    NaN    NaN  17.04.2024 11:09:52
#
#           Дата создания                        Источник Стадия Техника База
# 0   01.02.2023 14:22:23  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_cc = number_norm(data = contact_cc, name = 'Телефон', new_name='number')
# Out:
# (89, 11)
# 6

# %%
contact_ch = pd.read_csv('CONTACT_ч.csv', dtype=str)
display(contact_ch)
contact_ch['Телефон'].isnull().value_counts()
# Out:
#       Название      Телефон E-mail Регион Последняя активность  \
# 0         ГРАЧ  89299208608    NaN    NaN  01.02.2023 14:22:53
# 1     ВЯЧЕСЛАВ   9031110921    NaN    NaN  01.02.2023 14:22:49
# 2     ВЯЧЕСЛАВ  89256644704    NaN    NaN  01.02.2023 14:22:40
# 3     ВЯЧЕСЛАВ  89104303618    NaN    NaN  01.02.2023 14:22:26
# 4     ВЯЧЕСЛАВ   9037221944    NaN    NaN  01.02.2023 14:22:25
# ...        ...          ...    ...    ...                  ...
# 1537  ВЯЧЕСЛАВ      2116629    NaN    NaN  01.02.2023 10:18:43
# 1538  ВЯЧЕСЛАВ  89104261157    NaN    NaN  01.02.2023 10:18:38
# 1539  ВЯЧЕСЛАВ  89255023602    NaN    NaN  01.02.2023 10:18:17
# 1540    РЕ ЧУН  89037978877    NaN    NaN  01.02.2023 10:17:57
# 1541     МАХАЧ  89104506694    NaN    NaN  01.02.2023 10:17:55
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:53  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_ch = number_norm(data = contact_ch, name = 'Телефон', new_name='number')
# Out:
# (1542, 11)
# 138

# %%
contact_sh = pd.read_csv('CONTACT_ш.csv', dtype=str)
display(contact_sh)
contact_sh['Телефон'].isnull().value_counts()
# Out:
#          Название      Телефон E-mail Регион Последняя активность  \
# 0          ШАМИЛЬ   9168093955    NaN    NaN  01.02.2023 14:22:57
# 1           ШАХИН  89035593536    NaN    NaN  01.02.2023 14:22:42
# 2    МАГОМЕДШАРИП   9036288630    NaN    NaN  01.02.2023 14:22:12
# 3          ШАМИЛЬ  89030055990    NaN    NaN  01.02.2023 14:22:06
# 4         АЙКАНУШ  89166190190    NaN    NaN  01.02.2023 14:21:54
# ..            ...          ...    ...    ...                  ...
# 686   БАЛАГАНЕШАН  89263614112    NaN    NaN  01.02.2023 10:18:26
# 687        ШОРЕНА  89166098255    NaN    NaN  01.02.2023 10:18:20
# 688          АШОТ  89252370007    NaN    NaN  01.02.2023 10:18:04
# 689        ШАМИЛЬ  89263009202    NaN    NaN  01.02.2023 10:18:01
# 690       СИЯБШАХ  89153093454    NaN    NaN  01.02.2023 10:17:59
#
#            Дата создания                        Источник Стадия Техника База
# 0    01.02.2023 14:22:57  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_sh = number_norm(data = contact_sh, name = 'Телефон', new_name='number')
# Out:
# (691, 11)
# 50

# %%
contact_ui = pd.read_csv('CONTACT_ы.csv', dtype=str)
display(contact_ui)
contact_ui['Телефон'].isnull().value_counts()
# Out:
#      Название      Телефон E-mail Регион Последняя активность  \
# 0     БАХАДЫР  89651527202    NaN    NaN  01.02.2023 14:20:23
# 1     БАХАДЫР  89262677057    NaN    NaN  01.02.2023 14:20:19
# 2       ФАТЫХ  89055059820    NaN    NaN  01.02.2023 14:19:47
# 3    БАКЫТБЕК  89165175063    NaN    NaN  01.02.2023 14:10:30
# 4      ЦАНДЫК  89651222809    NaN    NaN  01.02.2023 14:08:55
# ..        ...          ...    ...    ...                  ...
# 153    ДАШГЫН  84953477202    NaN    NaN  01.02.2023 10:21:17
# 154     САДЫХ   8926535353    NaN    NaN  01.02.2023 10:20:47
# 155  БАТЫРБЕК  89299998807    NaN    NaN  01.02.2023 10:20:19
# 156     САДЫХ   4956195005    NaN    NaN  01.02.2023 10:19:29
# 157     НАЗЫМ      5173930    NaN    NaN  01.02.2023 10:18:56
#
#            Дата создания                        Источник Стадия Техника База
# 0    01.02.2023 14:20:23  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_ui = number_norm(data = contact_ui, name = 'Телефон', new_name='number')
# Out:
# (158, 11)
# 7

# %%
contact_q = pd.read_csv('CONTACT_ь.csv', dtype=str)
display(contact_q)
contact_q['Телефон'].isnull().value_counts()
# Out:
#       Название                                            Телефон E-mail  \
# 0        Дарья                                        79956054851    NaN
# 1       ШАМИЛЬ                                         9168093955    NaN
# 2      НАТАЛЬЯ                                         9670425317    NaN
# 3      ТАТЬЯНА                                        89057071314    NaN
# 4        ИГОРЬ                                        89161953242    NaN
# ...        ...                                                ...    ...
# 15758  НАТАЛЬЯ  89039727575, 89296151023, 89175125693, 8916672...    NaN
# 15759    ИГОРЬ                                        89099092921    NaN
# 15760     ИЛЬЯ                                        89037780848    NaN
# 15761  ТАТЬЯНА                                        89262651187    NaN
# 15762     Илья                                        79164458410    NaN
#
#       Регион Последняя активность        Дата создания  \
# ...

# %%
cont_q = number_norm(data = contact_q, name = 'Телефон', new_name='number')
# Out:
# (15763, 11)
# 1059

# %%
contact_qe = pd.read_csv('CONTACT_э.csv', dtype=str)
display(contact_qe)
contact_qe['Телефон'].isnull().value_counts()
# Out:
#       Название      Телефон E-mail Регион Последняя активность  \
# 0       ЭДУАРД   9057071978    NaN    NaN  01.02.2023 14:22:38
# 1      РАФАЭЛЬ  89851949408    NaN    NaN  01.02.2023 14:22:36
# 2        ЭМИЛЬ  89099661415    NaN    NaN  01.02.2023 14:22:27
# 3       ЭДУАРД   9262646846    NaN    NaN  01.02.2023 14:21:49
# 4        ЭМИЛЬ  89091539545    NaN    NaN  01.02.2023 14:21:43
# ...        ...          ...    ...    ...                  ...
# 1180    ЭДУАРД  89629953959    NaN    NaN  01.02.2023 10:18:06
# 1181    МАРИНЭ  89150070385    NaN    NaN  01.02.2023 10:18:04
# 1182      ЭМИН      4650803    NaN    NaN  01.02.2023 10:17:59
# 1183  ЭЛЬБУРУС      1873187    NaN    NaN  01.02.2023 10:17:58
# 1184      ЭРИК  89262140343    NaN    NaN  01.02.2023 10:17:58
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:38  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_qe = number_norm(data = contact_qe, name = 'Телефон', new_name='number')
# Out:
# (1185, 11)
# 76

# %%
contact_u = pd.read_csv('CONTACT_ю.csv', dtype=str)
display(contact_u)
contact_u['Телефон'].isnull().value_counts()
# Out:
#      Название      Телефон E-mail Регион Последняя активность  \
# 0        ЮРИЙ  89266516894    NaN    NaN  01.02.2023 14:22:57
# 1        ЮРИЙ   9652259460    NaN    NaN  01.02.2023 14:22:56
# 2        ЮРИЙ  89039748786    NaN    NaN  01.02.2023 14:22:55
# 3        ЮРИЙ  89654387313    NaN    NaN  01.02.2023 14:22:53
# 4        ЮРИЙ   9057788889    NaN    NaN  01.02.2023 14:22:51
# ...       ...          ...    ...    ...                  ...
# 6510     ЮРИЙ  89851808835    NaN    NaN  01.02.2023 10:18:00
# 6511  ЛЮДМИЛА  89037810711    NaN    NaN  01.02.2023 10:17:59
# 6512   ЛЮБОВЬ  79035350847    NaN    NaN  01.02.2023 10:17:59
# 6513     ЮЛИЯ   9161764510    NaN    NaN  01.02.2023 10:17:58
# 6514  ЛЮДМИЛА      7436895    NaN    NaN  01.02.2023 10:17:58
#
#             Дата создания                        Источник Стадия Техника База
# 0     01.02.2023 14:22:57  Холодная база - еще не звонили    NaN     NaN  NaN
# ...

# %%
cont_u = number_norm(data = contact_u, name = 'Телефон', new_name='number')
# Out:
# (6515, 11)
# 526

# %%
contact_ya = pd.read_csv('CONTACT_я.csv', dtype=str)
display(contact_ya)
contact_ya['Телефон'].isnull().value_counts()
# Out:
#       Название                                            Телефон E-mail  \
# 0        Дарья                                        79956054851    NaN
# 1      НАТАЛЬЯ                                         9670425317    NaN
# 2      ТАТЬЯНА                                        89057071314    NaN
# 3        ЛИДИЯ                                        89263553399    NaN
# 4      НАТАЛИЯ                                        89067223744    NaN
# ...        ...                                                ...    ...
# 17908  НАТАЛЬЯ  89039727575, 89296151023, 89175125693, 8916672...    NaN
# 17909     ИЛЬЯ                                        89037780848    NaN
# 17910  ЯРОСЛАВ                                        84957680432    NaN
# 17911  ТАТЬЯНА                                        89262651187    NaN
# 17912     Илья                                        79164458410    NaN
#
#       Регион Последняя активность        Дата создания  \
# ...

# %%
cont_ya = number_norm(data = contact_ya, name = 'Телефон', new_name='number')
# Out:
# (17913, 11)
# 1134

# %%
contact_r = pd.read_csv('CONTACT_р.csv', dtype=str)
display(contact_r)
contact_r['Телефон'].isnull().value_counts()
# Out:
#              Название      Телефон E-mail Регион Последняя активность  \
# 0               Дарья  79956054851    NaN    NaN  28.10.2023 10:56:51
# 1           АЛЕКСАНДР   9104489851    NaN    NaN  01.02.2023 14:22:57
# 2           ЕКАТЕРИНА  89645111050    NaN    NaN  01.02.2023 14:22:57
# 3              ВИКТОР   9264727051    NaN    NaN  01.02.2023 14:22:57
# 4               РОМАН  89031888883    NaN    NaN  01.02.2023 14:22:57
# ...               ...          ...    ...    ...                  ...
# 66050          Сергей  79994505505    NaN    NaN  11.01.2023 23:25:56
# 66051            Егор  79135937038    NaN    NaN  27.12.2022 13:00:01
# 66052  Отец Александр  79212238584    NaN    NaN  17.04.2024 11:09:52
# 66053          Андрей  79504024285    NaN    NaN  14.06.2024 10:41:14
# 66054           Ринат  79163479836    NaN    NaN  28.02.2023 20:45:30
#
#              Дата создания                        Источник Стадия Техника База
# ...

# %%
cont_r = number_norm(data = contact_r, name = 'Телефон', new_name='number')
# Out:
# (66055, 11)
# 5267

# %%
#merged_df = cont_a.merge(cont_b, how='outer', on='number', sort=True)
#display(merged_df)
#display(cont_a.shape[0]+cont_b.shape[0])

# %%
concat_df = pd.concat([cont_a, cont_b, cont_c, cont_cc, cont_ch, 
                       cont_d, cont_e, cont_f, cont_g, cont_i, 
                       cont_ii, cont_j, cont_k, cont_l, cont_m, 
                       cont_n, cont_o, cont_p, cont_r, cont_q, 
                       cont_qe, cont_t, cont_sh, cont_u, cont_ui, 
                       cont_v, cont_x, cont_y, cont_ya, cont_z], sort=True, ignore_index=True)
display(concat_df.shape)
display(cont_a.shape[0]+cont_b.shape[0])
# Out:
# (719259, 12)
# 95684

# %%
display(concat_df)
concat_df['number'].value_counts()[lambda x: x>1]
# Out:
#        E-mail       number База        Дата создания Емейл  \
# 0         NaN  79875151111  NaN  26.04.2023 11:21:55   NaN
# 1         NaN  79956054851  NaN  28.03.2023 11:53:27   NaN
# 2         NaN  79168093955  NaN  01.02.2023 14:22:57   NaN
# 3         NaN  79104489851  NaN  01.02.2023 14:22:57   NaN
# 4         NaN  79250069996  NaN  01.02.2023 14:22:57   NaN
# ...       ...          ...  ...                  ...   ...
# 719254    NaN  79095384400  NaN  01.02.2023 10:18:11   NaN
# 719255    NaN  79852260937  NaN  01.02.2023 10:18:10   NaN
# 719256    NaN  79266606646  NaN  01.02.2023 10:18:04   NaN
# 719257    NaN  79252204581  NaN  01.02.2023 10:18:02   NaN
# 719258    NaN  79152222877  NaN  01.02.2023 10:17:58   NaN
#
#                               Источник   Название Последняя активность Регион  \
# 0                                  NaN    Алексей  22.05.2023 12:12:04    NaN
# 1                               Звонок      Дарья  28.10.2023 10:56:51    NaN
# ...

# %%
concat_df_drop_dubl = concat_df.drop_duplicates('number', ignore_index=True)
display(concat_df_drop_dubl)
# Out:
#        E-mail       number База        Дата создания Емейл  \
# 0         NaN  79875151111  NaN  26.04.2023 11:21:55   NaN
# 1         NaN  79956054851  NaN  28.03.2023 11:53:27   NaN
# 2         NaN  79168093955  NaN  01.02.2023 14:22:57   NaN
# 3         NaN  79104489851  NaN  01.02.2023 14:22:57   NaN
# 4         NaN  79250069996  NaN  01.02.2023 14:22:57   NaN
# ...       ...          ...  ...                  ...   ...
# 129648    NaN  79100023838  NaN  01.02.2023 11:09:12   NaN
# 129649    NaN  79015172258  NaN  01.02.2023 12:44:16   NaN
# 129650    NaN  79165450983  NaN  01.02.2023 10:56:50   NaN
# 129651    NaN  79165167980  NaN  01.02.2023 11:45:15   NaN
# 129652    NaN  79683629999  NaN  01.02.2023 11:42:21   NaN
#
#                               Источник   Название Последняя активность Регион  \
# 0                                  NaN    Алексей  22.05.2023 12:12:04    NaN
# 1                               Звонок      Дарья  28.10.2023 10:56:51    NaN
# ...

# %%
concat_df_drop_dubl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129653 entries, 0 to 129652
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   E-mail                0 non-null       object
#  1   number                129653 non-null  object
#  2   База                  0 non-null       object
#  3   Дата создания         129653 non-null  object
#  4   Емейл                 0 non-null       object
#  5   Источник              129649 non-null  object
#  6   Название              129653 non-null  object
#  7   Последняя активность  129653 non-null  object
#  8   Регион                0 non-null       object
#  9   Стадия                0 non-null       object
#  10  Телефон               129653 non-null  object
#  11  Техника               0 non-null       object
# dtypes: object(12)
# memory usage: 11.9+ MB

# %%
concat_df_drop_dubl.to_csv('CONTACT_all.csv')
